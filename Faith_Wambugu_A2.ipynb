# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %%
listings = pd.read_csv("Airbnb_NYC_2019.csv")

# %%
listings
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#Create a histogram for all prices
plt.hist(listings["price"], bins = np.arange(0, 1100, 40))
plt.title("Distribution of Airbnb NYC listing prices in 2019")
plt.xlabel("Price(in US dollars)")
plt.ylabel("Count")
plt.show()

# %%
#Create a scatter plot of price over no. of reviews
plt.scatter(x = listings["price"],y = listings["number_of_reviews"])
plt.title("Scatter plot for Number of reviews vs Price of Airbnb NYC Listings for 2019")
plt.xlabel("Price(in US dollars)")
plt.ylabel("Number of Reviews")
plt.show()

# %%
#If you want to zoom in on x axis
plt.scatter(x = listings["price"],y = listings["number_of_reviews"], s = 5)
plt.xlim(0, 1100)
plt.title("Scatter plot for Number of reviews vs Price of Airbnb NYC Listings for 2019")
plt.xlabel("Price(in US dollars)")
plt.ylabel("Number of Reviews")
plt.show()

# %%
#bar chart that displays the count of bnb listings 
# in each neighborhood group of NYC from listings df
sn.countplot(x = "neighbourhood_group", data = listings )
plt.title("Airbnb listings per neighbourhood group in 2019")
plt.show()

# %%
#Barchart for ave. price of Airbnb listings in 
#each neighbourhood group of NYC from listings df
#black lines mark confidence intervals
sn.barplot(x = "neighbourhood_group", y = "price", data = listings)
plt.show()

# %%
# ci =  false to remove the black lines
sn.barplot(x = "neighbourhood_group", y = "price", data = listings, ci = False)
plt.show()

# %%
#Select a subset of manhattan neighbourhood group from listings df
listings.loc[["Manhattan" in neighbourhood_group for neighbourhood_group in listings["neighbourhood_group"]],:]
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 7          5178                   Large Furnished Room Near B'way        8967
# ...         ...                                                ...        ...
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
#Give the subset a df
listings_subset = listings.loc[["Manhattan" in neighbourhood_group for neighbourhood_group in listings["neighbourhood_group"]],:]

# %%
listings_subset
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 7          5178                   Large Furnished Room Near B'way        8967
# ...         ...                                                ...        ...
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
#No. of rows and columns in the subset
listings_subset.shape
# Out:
# (21661, 16)

# %%
#Countplot for all neighbourhoods of Manhattan
plt.figure(figsize=(18, 9))
sn.countplot(y = "neighbourhood",  data = listings_subset)
plt.title("Top 10 Manhattan neighbourhood bnbs in 2019")
plt.show()

# %%
#neighbourhoods with ten highest counts
#listings_Manhattan10 = listings_subset.sort_values("neighbourhood", ascending = False)#.groupby('neighbourhood')
#listings_Manhattan10 = listings_subset['neighbourhood'].value_counts(ascending=False).reset_index()
#listings_Manhattan10 = listings_subset['neighbourhood'].value_counts()
#listings_Manhattan10 = listings_subset.groupby('neighbourhood').count()
listings_Manhattan10 = listings_subset.value_counts(subset='neighbourhood',sort=True,ascending=False)
listings_Manhattan10
# Out:
# neighbourhood
# Harlem                 2658
# Upper West Side        1971
# Hell's Kitchen         1958
# East Village           1853
# Upper East Side        1798
# Midtown                1545
# East Harlem            1117
# Chelsea                1113
# Lower East Side         911
# Washington Heights      899
# West Village            768
# Financial District      744
# Murray Hill             485
# Kips Bay                470
# Greenwich Village       392
# Chinatown               368
# SoHo                    358
# Morningside Heights     346
# Gramercy                338
# Theater District        288
# Nolita                  253
# Inwood                  252
# Tribeca                 177
# Little Italy            121
# Flatiron District        80
# NoHo                     78
# Roosevelt Island         77
# Two Bridges              72
# Battery Park City        70
# Civic Center             52
# Stuyvesant Town          37
# Marble Hill              12
# dtype: int64

# %%
#Order of 1st to 10th highest count
listings_Manhattan10.iloc[0:10]
# Out:
# neighbourhood
# Harlem                2658
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Midtown               1545
# East Harlem           1117
# Chelsea               1113
# Lower East Side        911
# Washington Heights     899
# dtype: int64

# %%
#Subset corresponding to top 10
filter1 = listings_subset[listings_subset["neighbourhood"].isin(["Harlem","Upper West Side","Hell's Kitchen","East Village","Upper East Side","Midtown","East Harlem","Chelsea","Lower East Side","Washington Heights"])]
filter1
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# ...         ...                                                ...        ...
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
#Number of rows and columns in top 10 subset
filter1.shape
# Out:
# (15823, 16)

# %%
#Countplot that displays bnb listings in each of 
#those top 10 neighbourhoods in Manhattan
plt.figure(figsize=(18,2))
sn.countplot(x = 'neighbourhood',data=filter1)
plt.title("Top 10 Manhattan neighbourhood bnbs in 2019")
plt.show()

# %%
#Histogram for distr. of prices for manhattan listings
plt.hist(listings_subset["price"])
plt.title("Distribution of Airbnb Manhattan listing prices in 2019")
plt.xlabel("Price(in US dollars)")
plt.ylabel("Count")
plt.show()

# %%
#Include bins to zoom
plt.hist(listings_subset["price"], bins = np.arange(0, 1000, 40))
plt.title("Distribution of Airbnb Manhattan listing prices in 2019")
plt.xlabel("Price(in US dollars)")
plt.ylabel("Count")
plt.show()

# %%
#Scatter plot for no. of reviews over price for Manhattan listings
plt.scatter(x = listings_subset["price"],y = listings_subset["number_of_reviews"])
plt.title("Scatter plot for Number of reviews vs Price of Airbnb Manhattan Listings for 2019")
plt.xlabel("Price(in US dollars)")
plt.ylabel("Number of Reviews")
plt.show()

# %%
#If you want to zoom in on x axis
plt.scatter(x = listings_subset["price"],y = listings_subset["number_of_reviews"], s = 5)
plt.xlim(0, 2000)
plt.title("Scatter plot for Number of reviews vs Price of Airbnb NYC Listings for 2019")
plt.xlabel("Price(in US dollars)")
plt.ylabel("Number of Reviews")
plt.show()

# %%
#If you want to zoom in on x axis
plt.scatter(x = listings_subset["price"],y = listings_subset["number_of_reviews"], s = 3)
plt.xlim(0, 1000)
plt.title("Scatter plot for Number of reviews vs Price of Airbnb Manhattan Listings for 2019")
plt.xlabel("Price(in US dollars)")
plt.ylabel("Number of Reviews")
plt.show()
